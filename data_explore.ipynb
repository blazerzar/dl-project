# %% [markdown]
# # Data exploration

# %%
from os import listdir

import numpy as np
import pandas as pd
import torchaudio

METADATA_DEV = 'data/metadata_dev'
FOA_DEV = 'data/foa_dev'

# %% [markdown]
# Traget sound events are:
#
# 0. Female speech, woman speaking
# 1. Male speech, man speaking
# 2. Clapping
# 3. Telephone
# 4. Laughter
# 5. Domestic sounds
# 6. Walk, footsteps
# 7. Door, open or close
# 8. Music
# 9. Musical instrument
# 10. Water tap, faucet
# 11. Bell
# 12. Knock
#
# The metadata CSV files have the following columns:
#
# -   frame number (int): 0, 1, ..., resolution of 100 ms
# -   active class index (int): 0, 1, ...
# -   source number index (int): 0, 1, ..., unique integer for each source
# -   azimuth (int): [-180, 180], front = 0
# -   elevation (int): [-90, 90], left = 90
# -   distance (int): centimeters
#
# Multiple events of the same class can occur at the same time, each having a
# different source index. Occurrences of up to 3 simultaneous events are fairly
# common, while higher numbers of overlapping events (up to 5) can occur but are
# rare.

# %%
columns = ['frame', 'class', 'source', 'azimuth', 'elevation', 'distance']


def check_meta_file(file, dir):
    df = pd.read_csv(f'{METADATA_DEV}/{dir}/{file}', header=None, names=columns)
    max_frame = df['frame'].max()
    classes_per_frame = df.groupby('frame')['class'].nunique().max()
    class_instances_per_frame = df.groupby(['frame', 'class']).size().max()
    instances_per_frame = df.groupby('frame').size().max()

    annotated_frames = df['frame'].nunique()
    multi_event_frames = df.groupby('frame').size().gt(1).sum()
    multi_instance_frames = df.groupby(['frame', 'class']).size().gt(1).sum()

    filename, _ = file.split('.')
    waveform, sample_rate = torchaudio.load(f'{FOA_DEV}/{dir}/{filename}.wav')
    frames = waveform.shape[1] / sample_rate * 10
    print(
        f'  {filename:>19}: {frames:6.1f} ({max_frame:4}) frames, '
        f'{classes_per_frame} cls, {class_instances_per_frame} cls inst, '
        f'{instances_per_frame} insts'
    )

    return (
        frames,
        classes_per_frame,
        class_instances_per_frame,
        instances_per_frame,
        annotated_frames / max_frame,
        multi_event_frames / annotated_frames,
        multi_instance_frames / annotated_frames,
    )

# %%
weights = np.zeros(4)
annotated_ratios = np.zeros(4)
multi_event_ratios = np.zeros(4)
multi_instance_ratios = np.zeros(4)

for i, dir in enumerate(listdir(METADATA_DEV)):
    files = listdir(f'{METADATA_DEV}/{dir}')
    print(f'Directory: {dir}')
    print(f'Files: {len(files)}')

    seconds, max_frames = 0, 0
    max_classes, max_class_instances, max_instances = 0, 0, 0
    annotated_ratio = np.zeros(len(files))
    multi_event_ratio = np.zeros(len(files))
    multi_instance_ratio = np.zeros(len(files))
    for j, file in enumerate(files):
        (
            frames,
            classes,
            class_instances,
            instances,
            annotated,
            multi_event,
            multi_instance,
        ) = check_meta_file(file, dir)

        seconds += frames / 10
        max_frames = max(max_frames, frames)
        max_classes = max(max_classes, classes)
        max_class_instances = max(max_class_instances, class_instances)
        max_instances = max(max_instances, instances)

        annotated_ratio[j] = annotated
        multi_event_ratio[j] = multi_event
        multi_instance_ratio[j] = multi_instance
    print(
        f'Max frames: {max_frames:.1f}, '
        f'Max classes: {max_classes}, '
        f'Max class instances: {max_class_instances}, '
        f'Max instances: {max_instances}\n'
        f'Hours: {seconds / 3600:.1f}h, '
        f'Annotated: {annotated.mean():.2%}, '
        f'Multi-class: {multi_event.mean():.2%}, '
        f'Multi-instance: {multi_instance.mean():.2%}\n'
    )

    weights[i] = seconds
    annotated_ratios[i] = annotated_ratio.mean()
    multi_event_ratios[i] = multi_event_ratio.mean()
    multi_instance_ratios[i] = multi_instance_ratio.mean()

weights /= weights.sum()
# Out:
# Directory: dev-test-tau
# Files: 48
#   fold4_room16_mix004: 1418.8 (1373) frames, 3 cls, 2 cls inst, 4 insts
#   fold4_room16_mix003: 1311.5 (1311) frames, 3 cls, 2 cls inst, 4 insts
#   fold4_room16_mix014:  960.2 ( 909) frames, 3 cls, 1 cls inst, 3 insts
#    fold4_room8_mix008: 1672.5 (1629) frames, 2 cls, 3 cls inst, 3 insts
#   fold4_room16_mix002: 1267.4 (1267) frames, 2 cls, 2 cls inst, 3 insts
#   fold4_room16_mix007: 2045.4 (2000) frames, 2 cls, 2 cls inst, 2 insts
#    fold4_room2_mix003: 2534.1 (2489) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room15_mix010: 5692.3 (5625) frames, 1 cls, 1 cls inst, 1 insts
#   fold4_room16_mix005:  477.9 ( 505) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room16_mix009:  840.7 ( 810) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room10_mix004: 1480.7 (1429) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room10_mix001: 1378.7 (1339) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room15_mix009: 2237.4 (2216) frames, 3 cls, 2 cls inst, 5 insts
#   fold4_room10_mix006: 1704.9 (1664) frames, 2 cls, 1 cls inst, 2 insts
#    fold4_room2_mix004: 1703.4 (1674) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room15_mix005: 1269.5 (1250) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room15_mix002: 1805.2 (1777) frames, 1 cls, 1 cls inst, 1 insts
#   fold4_room10_mix007: 1443.3 (1389) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room16_mix001: 2198.1 (2143) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room16_mix012: 1411.6 (1386) frames, 4 cls, 3 cls inst, 5 insts
#   fold4_room16_mix011: 1754.0 (1740) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room15_mix006: 2987.5 (2930) frames, 3 cls, 3 cls inst, 3 insts
#   fold4_room15_mix001: 1634.9 (1623) frames, 1 cls, 1 cls inst, 1 insts
#   fold4_room16_mix006: 1759.5 (1719) frames, 2 cls, 1 cls inst, 2 insts
#    fold4_room2_mix002: 2729.9 (2704) frames, 3 cls, 2 cls inst, 4 insts
#   fold4_room10_mix008: 1469.8 (1424) frames, 2 cls, 1 cls inst, 2 insts
#    fold4_room2_mix005: 1836.1 (1809) frames, 3 cls, 1 cls inst, 3 insts
#    fold4_room8_mix004: 1063.0 (1024) frames, 4 cls, 2 cls inst, 4 insts
#    fold4_room8_mix001: 2081.4 (2019) frames, 2 cls, 2 cls inst, 3 insts
#   fold4_room15_mix004: 2866.7 (2828) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room16_mix013: 1208.1 (1140) frames, 4 cls, 3 cls inst, 4 insts
#   fold4_room16_mix010: 1319.2 (1291) frames, 3 cls, 2 cls inst, 4 insts
#   fold4_room10_mix005: 1160.2 (1104) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room10_mix002: 1449.1 (1399) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room10_mix009: 1620.2 (1579) frames, 3 cls, 2 cls inst, 3 insts
#    fold4_room8_mix007: 1336.0 (1304) frames, 2 cls, 3 cls inst, 3 insts
#   fold4_room15_mix007: 2307.1 (2291) frames, 3 cls, 3 cls inst, 4 insts
#    fold4_room8_mix003: 2135.2 (2089) frames, 2 cls, 4 cls inst, 5 insts
#    fold4_room2_mix006: 3490.7 (3469) frames, 2 cls, 2 cls inst, 2 insts
#    fold4_room8_mix006: 2250.6 (2234) frames, 3 cls, 2 cls inst, 5 insts
#    fold4_room8_mix005: 1752.7 (1644) frames, 2 cls, 2 cls inst, 3 insts
#   fold4_room15_mix003: 2726.1 (2709) frames, 1 cls, 1 cls inst, 1 insts
#   fold4_room16_mix008:  455.2 ( 421) frames, 3 cls, 1 cls inst, 3 insts
#    fold4_room8_mix002: 1878.5 (1859) frames, 2 cls, 3 cls inst, 4 insts
#   fold4_room10_mix003: 1402.6 (1344) frames, 1 cls, 1 cls inst, 1 insts
#   fold4_room15_mix008: 1524.9 (1491) frames, 2 cls, 2 cls inst, 3 insts
#    fold4_room2_mix001: 1492.8 (1441) frames, 2 cls, 2 cls inst, 3 insts
#    fold4_room8_mix009: 3591.6 (3559) frames, 3 cls, 2 cls inst, 3 insts
# Max frames: 5692.3, Max classes: 4, Max class instances: 4, Max instances: 5
# Hours: 2.4h, Annotated: 85.84%, Multi-class: 10.15%, Multi-instance: 4.91%
#
# Directory: dev-train-tau
# Files: 50
#   fold3_room13_mix008: 2358.6 (2348) frames, 4 cls, 3 cls inst, 4 insts
#   fold3_room12_mix004: 3351.4 (3335) frames, 3 cls, 1 cls inst, 3 insts
#    fold3_room9_mix002: 1722.6 (1624) frames, 1 cls, 2 cls inst, 2 insts
#    fold3_room6_mix002: 2577.8 (2549) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room14_mix001: 1065.1 ( 982) frames, 2 cls, 2 cls inst, 3 insts
#   fold3_room13_mix005:  534.2 ( 520) frames, 3 cls, 2 cls inst, 4 insts
#   fold3_room12_mix006: 1550.2 (1527) frames, 3 cls, 3 cls inst, 3 insts
#   fold3_room12_mix007: 2487.4 (2451) frames, 3 cls, 3 cls inst, 4 insts
#   fold3_room12_mix009: 1037.8 (1017) frames, 4 cls, 2 cls inst, 5 insts
#    fold3_room4_mix008: 1663.9 (1614) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room7_mix001: 1545.9 (1469) frames, 2 cls, 2 cls inst, 3 insts
#   fold3_room14_mix002:  774.8 ( 711) frames, 2 cls, 2 cls inst, 3 insts
#   fold3_room13_mix002: 2966.8 (2892) frames, 2 cls, 2 cls inst, 3 insts
#    fold3_room6_mix001: 2198.1 (2169) frames, 3 cls, 2 cls inst, 3 insts
#    fold3_room4_mix005: 1094.5 (1029) frames, 1 cls, 1 cls inst, 1 insts
#    fold3_room9_mix004: 1464.9 (1414) frames, 1 cls, 2 cls inst, 2 insts
#   fold3_room12_mix001: 2532.9 (2523) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room9_mix007: 1604.0 (1574) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room6_mix006: 1014.5 ( 974) frames, 3 cls, 1 cls inst, 3 insts
#   fold3_room13_mix003: 2040.3 (2020) frames, 3 cls, 2 cls inst, 3 insts
#    fold3_room7_mix006: 3366.1 (3334) frames, 3 cls, 2 cls inst, 4 insts
#    fold3_room4_mix001: 1290.8 (1234) frames, 2 cls, 1 cls inst, 2 insts
#   fold3_room12_mix008: 2451.1 (2433) frames, 5 cls, 2 cls inst, 5 insts
#   fold3_room12_mix005:  948.4 ( 925) frames, 3 cls, 1 cls inst, 3 insts
#    fold3_room7_mix004: 3284.2 (3244) frames, 2 cls, 2 cls inst, 2 insts
#    fold3_room7_mix003: 2183.6 (2144) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room13_mix009: 3886.0 (3866) frames, 4 cls, 2 cls inst, 6 insts
#   fold3_room14_mix003:  408.7 ( 345) frames, 3 cls, 2 cls inst, 3 insts
#    fold3_room9_mix008: 2138.8 (2114) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room7_mix002: 3254.3 (3214) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room13_mix007: 2443.3 (2440) frames, 3 cls, 2 cls inst, 3 insts
#    fold3_room6_mix007: 2145.8 (2094) frames, 2 cls, 1 cls inst, 2 insts
#   fold3_room14_mix004:  656.6 ( 589) frames, 2 cls, 2 cls inst, 3 insts
#   fold3_room12_mix002: 2247.2 (2229) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room9_mix003: 1645.4 (1609) frames, 2 cls, 2 cls inst, 2 insts
#    fold3_room9_mix006: 1487.3 (1454) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room6_mix003: 3219.3 (3184) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room9_mix005: 2298.4 (2249) frames, 2 cls, 1 cls inst, 2 insts
#    fold3_room7_mix005: 2604.3 (2549) frames, 2 cls, 2 cls inst, 2 insts
#    fold3_room4_mix006: 1817.9 (1764) frames, 2 cls, 2 cls inst, 2 insts
#    fold3_room9_mix001: 1807.5 (1754) frames, 1 cls, 2 cls inst, 2 insts
#   fold3_room13_mix004: 1555.8 (1508) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room12_mix003: 3547.9 (3533) frames, 3 cls, 1 cls inst, 3 insts
#    fold3_room4_mix004: 1597.4 (1478) frames, 1 cls, 1 cls inst, 1 insts
#   fold3_room13_mix006: 3078.1 (3055) frames, 2 cls, 2 cls inst, 2 insts
#    fold3_room4_mix007: 2242.7 (2219) frames, 2 cls, 2 cls inst, 2 insts
#    fold3_room6_mix004: 2895.1 (2869) frames, 2 cls, 1 cls inst, 2 insts
#   fold3_room12_mix010: 1927.8 (1859) frames, 3 cls, 2 cls inst, 4 insts
#    fold3_room6_mix005: 2740.0 (2704) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room13_mix001: 2631.0 (2607) frames, 3 cls, 2 cls inst, 3 insts
# Max frames: 3886.0, Max classes: 5, Max class instances: 3, Max instances: 6
# Hours: 2.9h, Annotated: 81.82%, Multi-class: 9.24%, Multi-instance: 1.88%
#
# Directory: dev-test-sony
# Files: 30
#   fold4_room23_mix013:  600.0 ( 599) frames, 3 cls, 1 cls inst, 3 insts
#   fold4_room23_mix006: 1047.0 (1046) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room24_mix016:  798.0 ( 797) frames, 3 cls, 2 cls inst, 4 insts
#   fold4_room23_mix005:  743.0 ( 728) frames, 2 cls, 2 cls inst, 2 insts
#   fold4_room23_mix008:  530.0 ( 529) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room24_mix013:  572.0 ( 571) frames, 5 cls, 2 cls inst, 5 insts
#   fold4_room24_mix008:  970.0 ( 969) frames, 3 cls, 1 cls inst, 3 insts
#   fold4_room24_mix009:  775.0 ( 773) frames, 3 cls, 1 cls inst, 3 insts
#   fold4_room23_mix010:  710.0 ( 709) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room24_mix012: 1568.0 (1567) frames, 3 cls, 1 cls inst, 3 insts
#   fold4_room24_mix007:  890.0 ( 889) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room23_mix011: 1150.0 (1149) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room23_mix002:  447.0 ( 446) frames, 4 cls, 2 cls inst, 4 insts
#   fold4_room24_mix010:  727.0 ( 710) frames, 3 cls, 1 cls inst, 3 insts
#   fold4_room24_mix005: 1373.0 (1372) frames, 4 cls, 2 cls inst, 4 insts
#   fold4_room23_mix014: 1200.0 (1200) frames, 4 cls, 2 cls inst, 4 insts
#   fold4_room23_mix001:  607.0 ( 606) frames, 4 cls, 2 cls inst, 4 insts
#   fold4_room23_mix004: 1022.0 (1021) frames, 4 cls, 2 cls inst, 4 insts
#   fold4_room24_mix011:  633.0 ( 632) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room24_mix002: 1054.0 (1053) frames, 5 cls, 1 cls inst, 5 insts
#   fold4_room24_mix014: 1256.0 (1250) frames, 5 cls, 2 cls inst, 5 insts
#   fold4_room23_mix009:  650.0 ( 649) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room24_mix003:  973.0 ( 972) frames, 4 cls, 1 cls inst, 4 insts
#   fold4_room24_mix004:  951.0 ( 950) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room24_mix015:  728.0 ( 408) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room24_mix006: 1410.0 (1409) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room23_mix012:  950.0 ( 949) frames, 2 cls, 1 cls inst, 2 insts
#   fold4_room24_mix001: 1789.0 (1787) frames, 3 cls, 2 cls inst, 3 insts
#   fold4_room23_mix003:  420.0 ( 419) frames, 3 cls, 2 cls inst, 4 insts
#   fold4_room23_mix007: 1260.0 (1259) frames, 2 cls, 2 cls inst, 3 insts
# Max frames: 1789.0, Max classes: 5, Max class instances: 2, Max instances: 5
# Hours: 0.8h, Annotated: 72.92%, Multi-class: 31.81%, Multi-instance: 23.42%
#
# Directory: dev-train-sony
# Files: 40
#   fold3_room21_mix016:  752.0 ( 737) frames, 2 cls, 2 cls inst, 3 insts
#   fold3_room21_mix022: 1750.0 (1739) frames, 2 cls, 2 cls inst, 4 insts
#   fold3_room21_mix013:  650.0 ( 649) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room21_mix007:  768.0 ( 767) frames, 2 cls, 2 cls inst, 3 insts
#   fold3_room21_mix002: 1400.0 (1387) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room22_mix002: 1195.0 (1181) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room21_mix028: 1000.0 ( 999) frames, 3 cls, 1 cls inst, 3 insts
#   fold3_room21_mix014:  680.0 ( 679) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room21_mix023: 1095.0 (1094) frames, 2 cls, 2 cls inst, 4 insts
#   fold3_room21_mix003: 1180.0 (1168) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room22_mix006:  600.0 ( 600) frames, 3 cls, 2 cls inst, 4 insts
#   fold3_room21_mix021: 1300.0 (1299) frames, 3 cls, 1 cls inst, 3 insts
#   fold3_room21_mix005:  680.0 ( 671) frames, 1 cls, 2 cls inst, 2 insts
#   fold3_room21_mix019:  490.0 ( 489) frames, 2 cls, 2 cls inst, 3 insts
#   fold3_room21_mix024:  840.0 ( 827) frames, 2 cls, 1 cls inst, 2 insts
#   fold3_room22_mix005: 1335.0 (1334) frames, 4 cls, 3 cls inst, 4 insts
#   fold3_room22_mix004: 1048.0 (1022) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room21_mix025: 2430.0 (2429) frames, 4 cls, 3 cls inst, 5 insts
#   fold3_room22_mix011: 1850.0 (1840) frames, 3 cls, 4 cls inst, 4 insts
#   fold3_room21_mix027: 1113.0 (1112) frames, 3 cls, 1 cls inst, 3 insts
#   fold3_room22_mix010: 2250.0 (2249) frames, 3 cls, 4 cls inst, 4 insts
#   fold3_room21_mix012: 1548.0 (1537) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room22_mix009:  854.0 ( 822) frames, 3 cls, 3 cls inst, 3 insts
#   fold3_room21_mix010:  945.0 ( 944) frames, 4 cls, 1 cls inst, 4 insts
#   fold3_room21_mix004:  325.0 ( 325) frames, 3 cls, 2 cls inst, 4 insts
#   fold3_room22_mix007: 1261.0 (1227) frames, 3 cls, 2 cls inst, 4 insts
#   fold3_room22_mix001:  750.0 ( 737) frames, 3 cls, 3 cls inst, 3 insts
#   fold3_room21_mix017: 1320.0 (1320) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room21_mix026: 2599.0 (2596) frames, 4 cls, 3 cls inst, 5 insts
#   fold3_room21_mix020: 1276.0 (1271) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room21_mix001:  894.0 ( 856) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room21_mix006:  379.0 ( 378) frames, 1 cls, 2 cls inst, 2 insts
#   fold3_room21_mix008: 1555.0 (1532) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room21_mix015: 1137.0 (1136) frames, 3 cls, 2 cls inst, 4 insts
#   fold3_room22_mix008:  950.0 ( 949) frames, 2 cls, 2 cls inst, 2 insts
#   fold3_room21_mix029: 2061.0 (2060) frames, 4 cls, 3 cls inst, 5 insts
#   fold3_room21_mix011:  586.0 ( 585) frames, 3 cls, 1 cls inst, 3 insts
#   fold3_room22_mix003:  695.0 ( 695) frames, 3 cls, 2 cls inst, 3 insts
#   fold3_room21_mix009: 1102.0 (1102) frames, 3 cls, 1 cls inst, 3 insts
#   fold3_room21_mix018: 1300.0 (1299) frames, 3 cls, 2 cls inst, 3 insts
# Max frames: 2599.0, Max classes: 4, Max class instances: 4, Max instances: 5
# Hours: 1.3h, Annotated: 100.00%, Multi-class: 45.73%, Multi-instance: 3.46%

# %% [markdown]
# Percentages of frames with:
#
# - at least one event,
# - at least two events,
# - at least two events of the same class.

# %%
print(f'Annotated: {np.sum(weights * annotated_ratios):.2%}')
print(f'Multi-event: {np.sum(weights * multi_event_ratios):.2%}')
print(f'Multi-instance: {np.sum(weights * multi_instance_ratios):.2%}')
# Out:
# Annotated: 85.21%
# Multi-event: 36.01%
# Multi-instance: 9.63%

# %% [markdown]
# ## Dataset length
#
# Train split: 1.3h + 2.9h = 4.2h
#
# Test split: 0.8h + 2.4h = 3.2h
